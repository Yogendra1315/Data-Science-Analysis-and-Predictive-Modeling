# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("international_matches.csv")
dataset
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
dataset.shape
# Out:
# (23921, 25)

# %%
dataset.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_team_continent',
#        'away_team_continent', 'home_team_fifa_rank', 'away_team_fifa_rank',
#        'home_team_total_fifa_points', 'away_team_total_fifa_points',
#        'home_team_score', 'away_team_score', 'tournament', 'city', 'country',
#        'neutral_location', 'shoot_out', 'home_team_result',
#        'home_team_goalkeeper_score', 'away_team_goalkeeper_score',
#        'home_team_mean_defense_score', 'home_team_mean_offense_score',
#        'home_team_mean_midfield_score', 'away_team_mean_defense_score',
#        'away_team_mean_offense_score', 'away_team_mean_midfield_score'],
#       dtype='object')

# %%
dataset['date'].unique()
# Out:
# array(['1993-08-08', '1993-08-09', '1993-08-11', ..., '2022-06-12',
#        '2022-06-13', '2022-06-14'], dtype=object)

# %%
dataset['away_team_score'].value_counts()
# Out:
# 0     9558
# 1     7759
# 2     4013
# 3     1551
# 4      594
# 5      214
# 6      107
# 7       67
# 8       27
# 10      11
# 9        9
# 11       3
# 12       2
# 15       2
# 17       1
# 21       1
# 13       1
# 14       1
# Name: away_team_score, dtype: int64

# %%
dataset.groupby(['home_team_continent','tournament'])['home_team_fifa_rank'].mean()
# Out:
# home_team_continent  tournament
# Africa               AFC Asian Cup qualification             156.500000
#                      AFC Challenge Cup                       156.500000
#                      AFC Challenge Cup qualification         159.500000
#                      African Cup of Nations                   54.930612
#                      African Cup of Nations qualification     97.388540
#                                                                 ...
# South America        Korea Cup                                62.000000
#                      Lunar New Year Cup                       28.000000
#                      Millennium Cup                           20.333333
#                      Superclásico de las Américas              6.125000
#                      USA Cup                                  30.000000
# Name: home_team_fifa_rank, Length: 164, dtype: float64

# %%
dataset
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
dataset.fillna(dataset.mean(),inplace=True)
dataset
# Out:
# /var/folders/p8/nk9crjd53hx48nj1yfs7_9jc0000gn/T/ipykernel_1190/1544217351.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.fillna(dataset.mean(),inplace=True)
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# ...

# %%
dataset.duplicated().any()
# Out:
# False

# %%
dataset.dtypes
# Out:
# date                              object
# home_team                         object
# away_team                         object
# home_team_continent               object
# away_team_continent               object
# home_team_fifa_rank                int64
# away_team_fifa_rank                int64
# home_team_total_fifa_points        int64
# away_team_total_fifa_points        int64
# home_team_score                    int64
# away_team_score                    int64
# tournament                        object
# city                              object
# country                           object
# neutral_location                    bool
# shoot_out                         object
# home_team_result                  object
# home_team_goalkeeper_score       float64
# away_team_goalkeeper_score       float64
# home_team_mean_defense_score     float64
# home_team_mean_offense_score     float64
# home_team_mean_midfield_score    float64
# away_team_mean_defense_score     float64
# ...

# %%
dataset.pivot_table(values=['home_team_score','away_team_score'],index=['tournament','home_team_continent','away_team_continent'],aggfunc=np.mean)
# Out:
#                                                                      away_team_score  \
# tournament                  home_team_continent away_team_continent
# ABCS Tournament             North America       North America               0.666667
#                                                 South America               1.500000
#                             South America       North America               0.000000
# AFC Asian Cup               Asia                Asia                        1.300000
#                                                 Oceania                     2.714286
# ...                                                                              ...
# VFF Cup                     Asia                Asia                        1.333333
# WAFF Championship           Asia                Asia                        0.882979
#                                                 Europe                      0.000000
# ...

# %%
temp=dataset['tournament'].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18,20))
plt.barh(temp.index,temp.values)
plt.tight_layout()

# %%
np.corrcoef(dataset['home_team_score'],dataset['home_team_goalkeeper_score'])
# Out:
# array([[1.        , 0.06222073],
#        [0.06222073, 1.        ]])

# %%
plt.hist(dataset['home_team_goalkeeper_score'])
# Out:
# (array([   51.,   148.,   227.,   811.,  1389., 17717.,  1713.,  1221.,
#           540.,   104.]),
#  array([47., 52., 57., 62., 67., 72., 77., 82., 87., 92., 97.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset['away_team_goalkeeper_score'])
# Out:
# (array([   68.,   163.,   236.,   886.,  1450., 17958.,  1569.,  1080.,
#           440.,    71.]),
#  array([47., 52., 57., 62., 67., 72., 77., 82., 87., 92., 97.]),
#  <BarContainer object of 10 artists>)

# %%
dataset.pivot_table(values=['home_team_total_fifa_points'],index=['tournament','home_team_continent'],aggfunc=np.sum)
# Out:
#                                                                 home_team_total_fifa_points
# tournament                                 home_team_continent
# ABCS Tournament                            North America                                537
#                                            South America                                635
# AFC Asian Cup                              Asia                                       72697
#                                            Oceania                                     6276
# AFC Asian Cup qualification                Africa                                      1774
# ...                                                                                     ...
# United Arab Emirates Friendship Tournament Oceania                                        0
# VFF Cup                                    Asia                                         442
# ...
